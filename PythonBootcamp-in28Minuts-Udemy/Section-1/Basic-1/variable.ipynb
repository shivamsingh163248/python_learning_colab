# %%
#generating the variable 
count = 10 
print(count)
#check what will the output 
#updating the variable 
count = 12 
print(count)
#if you ar the set in the double quos 
print("count")
print( "")
# Out:
# 10
# 12
# count

# %%
#type of the variable 
#variable should not start from the number
count  =20
Count  =20
_count =20
#1count =20
c1 =20
