# %%
#creating the print function in the python 
print("my name is the shivam singh ")
# Out:
# my name is the shivam singh

# %%
#learning the basic meths that is the required
print(5*5)
# Out:
# 25

# %%
print(5-5)
# Out:
# 0

# %%
print(5+5)
# Out:
# 10

# %%
print(10/5)
# Out:
# 2.0

# %%
print(10%2)
# Out:
# 0

# %%
print(10**2)
# Out:
# 100

# %%
#calculate the taal number of the minus 
print(24*60)
# Out:
# 1440

# %%
#calculate 
print("5+6")
# Out:
# 5+6

# %%
print('5+6')
# Out:
# 5+6

# %%
print(5+6)
# Out:
# 11

# %%
abs 10.5
# Out:
#   Cell In[14], line 1
#     abs 10.5
#         ^
# SyntaxError: invalid syntax

# %%
abs(10.5)
# Out:
# 10.5

# %%
abs("10.5")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 abs("10.5")
#
# TypeError: bad operand type for abs(): 'str'

# %%
pow 2 5
# Out:
#   Cell In[17], line 1
#     pow 2 5
#         ^
# SyntaxError: invalid syntax

# %%
pow(2,5)
# Out:
# 32

# %%
print( "hello world")
# Out:
# hello world

# %%
print("hello")
# Out:
# hello

# %%
#print escape
print("hello\"")
# Out:
# hello"

# %%
print("hello\nWorld")
# Out:
# hello
# World

# %%
print("hello\tWorld")
# Out:
# hello	World

# %%
print("Hello\\World")
# Out:
# Hello\World

# %%
print("Hello\\\\\\World")
# Out:
# Hello\\\World

# %%
print("Hello'World")
# Out:
# Hello'World
