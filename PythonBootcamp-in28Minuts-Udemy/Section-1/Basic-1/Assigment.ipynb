# %%
#learning the assignment of the variable 
i = 5 
j = i
i = 7
print(i)
print(j)
# Out:
# 7
# 5

# %%
#also possible to assign in the expression 
print(i+10)
# Out:
# 17

# %%
#again checking in the expression in the multiply 
print(j*2)
# Out:
# 10

# %%
j = 2*i

# %%
print(j)
# Out:
# 14

# %%
a = 5 
b = 6
c = 6
print(a+b+c)
# Out:
# 17

# %%
index = 0 
index = index+1 ; 
print(index)
# Out:
# 1
