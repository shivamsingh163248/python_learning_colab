# %%
#write about the nested loop 
#loop under one to other 
for i in range(10):
    for j in range(i):
        # creating the * printing 
        print("*", end=" ")
    print("*\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * * * *
#
# * * * * * * *
#
# * * * * * * * *
#
# * * * * * * * * *
#
# * * * * * * * * * *
