# %%
#creating the string manipulation 
print('shivam singh')
print("shivam singh")
# Out:
# shivam singh
# shivam singh

# %%
name = "shivam singh "
name_1 = 'itisha singh '

#check the type of the both
print(type(name))
print(type(name_1))
# Out:
# <class 'str'>
# <class 'str'>

# %%
print(name.upper())
print(name.lower())
# Out:
# SHIVAM SINGH
# shivam singh

# %%
print(name.capitalize())
# Out:
# Shivam singh

# %%
print("shivam".upper())
print("shivam".capitalize())
# Out:
# SHIVAM
# Shivam

# %%
#checking the is lower and isupper and isdigit 
print("shivam".islower())
print('Shivam'.islower())
# Out:
# True
# False

# %%
print("SHIVAM".isupper())
print("Shivam".isupper())
#checking is digit 
print('34'.isdigit())
print("shivam".isdigit())
# Out:
# True
# False
# True
# False

# %%
#checking is alpha 
print('abcd'.isalpha())
print('ABC1'.isalpha())
print('ABC'.isalpha())
print('ABC1'.isalnum())
print('ABC 1'.isalnum())
# Out:
# True
# False
# True
# True
# False
