# %%
#creating the string manipulation 
print('shivam singh')
print("shivam singh")
# Out:
# shivam singh
# shivam singh

# %%
name = "shivam singh "
name_1 = 'itisha singh '

#check the type of the both
print(type(name))
print(type(name_1))
# Out:
# <class 'str'>
# <class 'str'>
