# %%
#learning the data type 
a = 5 
type(a)
# Out:
# int

# %%
b= 3.5
#checking the type 
type(b)
# Out:
# float

# %%
#checking for the string of the number 
name = "my name is shivam singh "
type(name)
# Out:
# str

# %%
print(5/2)
# Out:
# 2.5

# %%
print(abs(2.5))
# Out:
# 2.5

# %%
print(int(2.5))
# Out:
# 2

# %%
value1 = 4.5
i = 10 

print(value1-1)
print(value1+1)
print(value1/1)
print(value1*1)
# Out:
# 3.5
# 5.5
# 4.5
# 4.5

# %%
i = 2
print(i)
i += 3
print(i)
# Out:
# 2
# 5

# %%
#division 
#learning the integer 

num = 5/9
print(num)

num_a = 5//9
print(num_a)
# Out:
# 0.5555555555555556
# 0

# %%
#pow function or the exponent operator 
print(pow(5,3))
print(5**3)
# Out:
# 125
# 125

# %%
i = 0 ; 
i += 1 ; 
print(i)
i *= 1 ; 
print(i)
i -= 1 ; 
print(i)
# Out:
# 1
# 1
# 0

# %%
print(int(3.5+67))
# Out:
# 70

# %%
#creating the round function 
print(round(5.67676))
# Out:
# 6

# %%
print(round(3.67676))
# Out:
# 4

# %%
print(float(3))
# Out:
# 3.0

# %%
#creating the round position at 1 decimal point 
#and creating the 2 decimal point 
print(round(5.35  ,1))
print(round(5.783,2))
# Out:
# 5.3
# 5.78

# %%
#checking the float values is the printing the approximate value 
print(35.66-34.6)
# Out:
# 1.0599999999999952

# %%
#this problem will be resolved using the Decimal class from the decimal module
from decimal import Decimal
#decimal values taking as the string  as the input 
number = Decimal("4.6")
print(number)
number1 = Decimal("74.6")
print(number1-number)
# Out:
# 4.6
# 70.0

# %%
is_even = 5>6

# %%
print(is_even)
# Out:
# False

# %%
is_even = True
is_odd = False

print(53>6)
# Out:
# True

# %%
print(type(is_even))
# Out:
# <class 'bool'>

# %%
#checking for the boolean convert to the integer 
true_name = True
result = int(true_name)
print(result)
# Out:
# 1

# %%
str = '212'
result = int(str)
print(result)
# Out:
# 212

# %%
str = '4'
result = int(str)
print(result)
# Out:
# 4

# %%
str = "212"
result = float(str)
print(result)
# Out:
# 212.0

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 num = 10
# ----> 2 result = str(num)
#
# TypeError: 'str' object is not callable
