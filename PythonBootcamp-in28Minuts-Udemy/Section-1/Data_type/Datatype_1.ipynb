# %%
#learning the data type 
a = 5 
type(a)
# Out:
# int

# %%
b= 3.5
#checking the type 
type(b)
# Out:
# float

# %%
#checking for the string of the number 
name = "my name is shivam singh "
type(name)
# Out:
# str

# %%
print(5/2)
# Out:
# 2.5

# %%
print(abs(2.5))
# Out:
# 2.5

# %%
print(int(2.5))
# Out:
# 2
