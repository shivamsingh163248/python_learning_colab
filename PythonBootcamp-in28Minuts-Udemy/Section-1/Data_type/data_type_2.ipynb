# %%
num = 10 
print(str(num))
# Out:
# 10

# %%
boolen_value = True 
print(str(boolen_value))
# Out:
# True

# %%
print('3')
# Out:
# 3

# %%
print(bool('4'))
# Out:
# True

# %%
print(bool('NaN'))
# Out:
# True

# %%
print(bool(-1))
# Out:
# True

# %%
result =  1  +  3  *  2  **  2  -  1  +  10  //  5  +  bool(-1)
print(result)
# Out:
# 15

# %%
z = input("enter")
print(type(z))
# Out:
# <class 'str'>

# %%
print(type(str(4.7)))
# Out:
# <class 'str'>

# %%
print(int("5"))
# Out:
# 5
