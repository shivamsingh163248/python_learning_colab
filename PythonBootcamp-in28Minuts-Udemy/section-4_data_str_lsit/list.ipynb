# %%
import random
import string

# Generate a list of 20 random strings
random_strings = [''.join(random.choices(string.ascii_letters + string.digits, k=8)) for _ in range(20)]
random_strings
# Out:
# ['J0uTlX8s',
#  '5ICmC5Fc',
#  'GX2FHzD4',
#  'bVgo0Xoj',
#  'qrTiKiuB',
#  '42SSnLxT',
#  'ugqvy5ZP',
#  'jYSYxcIl',
#  'xSi8kF78',
#  'LfQ4wQbH',
#  'knXR44S2',
#  'S50rpYpj',
#  'QdJvZJ4p',
#  'nxhKxGyJ',
#  'XoZx7tj0',
#  'pk32bV8e',
#  '9CsU9VPC',
#  'tzHpoASb',
#  'ylXoTFfF',
#  'Jruu6C0F']

# %%
fruits = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon', 
          'mango', 'nectarine', 'orange', 'papaya', 'quince', 'raspberry', 'strawberry', 'tangerine', 'ugli fruit', 'watermelon']

#creating 
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon', 'mango', 'nectarine', 'orange', 'papaya', 'quince', 'raspberry', 'strawberry', 'tangerine', 'ugli fruit', 'watermelon']

# %%
print(fruits[2:6])
# Out:
# ['cherry', 'date', 'elderberry', 'fig']

# %%
print(fruits[1:7])
# Out:
# ['banana', 'cherry', 'date', 'elderberry', 'fig', 'grape']

# %%
print(fruits[2:])
# Out:
# ['cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon', 'mango', 'nectarine', 'orange', 'papaya', 'quince', 'raspberry', 'strawberry', 'tangerine', 'ugli fruit', 'watermelon']

# %%
print(fruits[:10])
# Out:
# ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon']

# %%
print(fruits[::-2])
# Out:
# ['watermelon', 'tangerine', 'raspberry', 'papaya', 'nectarine', 'lemon', 'honeydew', 'fig', 'date', 'banana']

# %%
  numbers = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
 
print(len(numbers))  # Output: 10
 
print(numbers[2])    # Output: 'Two'
 
print(numbers[2:6])  # Output: ['Two', 'Three', 'Four', 'Five']

print(numbers[:6])  # Output: ['Zero', 'One', 'Two', 'Three', 'Four', 'Five']
print(numbers[3:])  # Output: ['Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']

print(numbers[1:8:2])  # Output: ['One', 'Three', 'Five', 'Seven']
print(numbers[1:8:3])  # Output: ['One', 'Four', 'Seven']
print(numbers[::3])    # Output: ['Zero', 'Three', 'Six', 'Nine']


print(numbers[::-1])   # Output: ['Nine', 'Eight', 'Seven', 'Six', 'Five', 'Four', 'Three', 'Two', 'One', 'Zero']
print(numbers[::-3])   # Output: ['Nine', 'Six', 'Three', 'Zero']

del numbers[3:]
print(numbers)         # Output: ['Zero', 'One', 'Two']
 
# Here, you mentioned `del numbers[5:7]`, but this slice 

numbers = ['Zero', 'One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
numbers[3:7] = [3, 4, 5, 6]
print(numbers)        # Output: ['Zero', 'One', 'Two', 3, 4, 5, 6, 'Seven', 'Eight', 'Nine']
# Out:
# 10
# Two
# ['Two', 'Three', 'Four', 'Five']
# ['Zero', 'One', 'Two', 'Three', 'Four', 'Five']
# ['Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine']
# ['One', 'Three', 'Five', 'Seven']
# ['One', 'Four', 'Seven']
# ['Zero', 'Three', 'Six', 'Nine']
# ['Nine', 'Eight', 'Seven', 'Six', 'Five', 'Four', 'Three', 'Two', 'One', 'Zero']
# ['Nine', 'Six', 'Three', 'Zero']
# ['Zero', 'One', 'Two']
# ['Zero', 'One', 'Two', 3, 4, 5, 6, 'Seven', 'Eight', 'Nine']

# %%
#creating the list 
list1 = []
#now appending the list 
list1.append(1)
list1.append(2)
list1.append(3)
list1.append(4)
print(list1)


#now removing the list 
list1.pop()
print(list1)
list1.remove(1)
print(list1)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]
# [2, 3]
