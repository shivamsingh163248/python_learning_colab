# %%
#creating the class of the stack 
class stack:
    #creating the arrays 
    #creating the constructor 
    def __init__(self):
        self.arr = []

    #now creating the method push 
    def push(self , element):
        self.arr.append(element)

    #creating the operation of the pop and return the last element and delete 
    def pop(self):
        return self.arr.pop()
    

    #find the last element 
    def last_ele(self):

        #creating the try and except 
        try:
            return self.arr[-1]
        except IndexError as e :
            print("my stack is empty")
            print(e)
        except:
            return -1 
    

    #creating the function isEmpty
    def isEmpty(self):
        #checking for the boolean 
        return not bool(self.arr) 
    


#creating the object 
new_obj = stack()
new_obj.push(4)
new_obj.push(5)

#noe pop the element 
print(new_obj.pop())
print(new_obj.last_ele())

print(new_obj.pop())

#checking the for the empty 
print(new_obj.isEmpty())
print(new_obj.last_ele())
# Out:
# 5
# 4
# 4
# True
# my stack is empty
# list index out of range
# None

# %%
#Check the remove function 
list2 = [456,6,674,4]
print(list2.index(6))
print(list2.remove(6))
print(list2)
# Out:
# 1
# None
# [456, 674, 4]

# %%
#now creating the queue 
class Queue:
    #creating and learning the queue 
    def __init__(self):
        self.Queue_list = []

    #creating the check of isEmpty of the list 
    def isEmpty(self):
        # length is zero that means is the list is empty 
        return len(self.Queue_list) == 0
    

    #creating the another push push 
    #push at the end and pop 
    def push(self , values):
         self.Queue_list.append(values)

    
    #now pop the element and return the the values 
    def pop(self):
        #check the isEmpty
        if not self.isEmpty:
            return self.Queue_list.pop(0)
        else:
            return "Queue is Empty "

# %%
# Now creating the queue
class Queue:
    # Creating and learning the queue
    def __init__(self):
        self.Queue_list = []

    # Check if the list is empty
    def isEmpty(self):
        return len(self.Queue_list) == 0

    # Push values to the end of the queue
    def push(self, values):
        self.Queue_list.append(values)

    # Pop element from the front of the queue
    def pop(self):
        # Corrected isEmpty check
        if not self.isEmpty():  # <-- Added parentheses here
            return self.Queue_list.pop(0)
        else:
            return "Queue is empty"

# Testing the Queue
q = Queue()
print(q.isEmpty())  # Expected: True (Queue is empty)

q.push(10)
q.push(20)
q.push(30)
print(q.isEmpty())  # Expected: False (Queue has elements)

print(q.pop())  # Expected: 10
print(q.pop())  # Expected: 20
print(q.pop())  # Expected: 30
print(q.pop())  # Expected: "Queue is empty"
# Out:
# True
# False
# 10
# 20
# 30
# Queue is empty
