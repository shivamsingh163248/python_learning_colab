# %%
#creating the lsit 
list_1 = [2,5,4,6,4,6]
list_2 = []
list_2 = ["shivam" , True , 5]

# %%
print(list_1[0])
# Out:
# 2

# %%
print(list_1[-2])
# Out:
# 4

# %%
#slice of the list 
list_1[0:3]
# Out:
# [2, 5, 4]

# %%
list_1[1:3]
# Out:
# [5, 4]

# %%
#fist to 5 
list_1[:4]
# Out:
# [2, 5, 4, 6]

# %%
list_1[3:]
# Out:
# [6, 4, 6]

# %%
#modieied the list 
list_1[2] = 10 
print(list_1)
# Out:
# [10, 5, 10, 10, 4, 6]

# %%
print(list_1*2)
# Out:
# [10, 5, 10, 10, 4, 6, 10, 5, 10, 10, 4, 6]

# %%
#adding element of the list '
print(list_1)
# Out:
# [10, 5, 10, 10, 4, 6]

# %%
#adding element of the list 
list_1.append(234)
print(list_1)
# Out:
# [10, 5, 10, 10, 4, 6, 234, 234]

# %%
#insert using at specific index 
list_1.insert(2,45)
print(list_1)
# Out:
# [10, 5, 45, 10, 10, 4, 6, 234, 234]

# %%
#extend and merge with the another list 
user_lsit_1 = [34,6,4,56,3,5]
user_lsit_2 = [4,6,3,4,23]

#i want to extend the list 
user_lsit_1.extend(list_2)
print(user_lsit_1)
# Out:
# [34, 6, 4, 56, 3, 5, 'shivam', True, 5]

# %%
#remove the first occurrence of element 6
user_lsit_1.remove(6)
print(user_lsit_1)
# Out:
# [34, 4, 56, 3, 5, 'shivam', True, 5]

# %%
print(user_lsit_1)
# Out:
# [34, 4, 56, 3, 5, 'shivam', True, 5]

# %%
#now removing the list 
#using the pop element 
newlist = user_lsit_1.pop()
print(newlist)
print(user_lsit_1)
newlist_1 = user_lsit_1.pop(3)
print(newlist_1)
print(user_lsit_1)
# Out:
# 56
# [34, 4]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 6
#       4 print(newlist)
#       5 print(user_lsit_1)
# ----> 6 newlist_1 = user_lsit_1.pop(3)
#       7 print(newlist_1)
#       8 print(user_lsit_1)
#
# IndexError: pop index out of range

# %%
user_lsit_1.clear()

# %%
print(user_lsit_1)
# Out:
# []

# %%
user_lsit_1.extend([5,10,4,2,10,10,4,10,3,5,10,10,4,4,4,10])
print(user_lsit_1)
# Out:
# [5, 10, 4, 2, 10, 10, 4, 10, 3, 5, 10, 10, 4, 4, 4, 10]

# %%
print(user_lsit_1.index(4))
# Out:
# 2

# %%
print(user_lsit_1.count(10))
# Out:
# 7

# %%
#creating the searching and shorting 
user_lsit_1.sort()
print(user_lsit_1)
# Out:
# [2, 3, 4, 4, 4, 4, 4, 5, 5, 10, 10, 10, 10, 10, 10, 10]

# %%
user_lsit_1.sort(reverse=True)
print(user_lsit_1)
# Out:
# [10, 10, 10, 10, 10, 10, 10, 5, 5, 4, 4, 4, 4, 4, 3, 2]

# %%
#now reversing the order 
user_lsit_1.reverse()
print(user_lsit_1)
# Out:
# [2, 3, 4, 4, 4, 4, 4, 5, 5, 10, 10, 10, 10, 10, 10, 10]

# %%
copy_new = user_lsit_1.copy()

# %%
#creating the new list 
new_list_3 = [i**2 for i in range(10) ]
print(new_list_3)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#creating the again new list 
new_list_4 = [i for i in range(11) if i%2 == 0]
print(new_list_4)
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
#now length of the list 
print(len(new_list_4))
# Out:
# 6

# %%
#now creating the type conversion of the list 
print(tuple(new_list_4))
# Out:
# (0, 2, 4, 6, 8, 10)

# %%
print(set(new_list_4))
# Out:
# {0, 2, 4, 6, 8, 10}

# %%
#its also can change in the string formate 
print(str(new_list_4)+"shivam")
# Out:
# [0, 2, 4, 6, 8, 10]shivam
