# %%
#creating the class of the nit 
class nit:
    #creating the constructor 
    def __init__(self):
        print("this is the nit collage")



#now creating the objet  and check this all  the 
cse = nit()
# Out:
# this is the nit collage

# %%
#see when creating the object the call the 
class nit :
    def __init__(self , branch):
        self.branch =  branch


s = nit("cse") 
print(s.branch)
# Out:
# cse
