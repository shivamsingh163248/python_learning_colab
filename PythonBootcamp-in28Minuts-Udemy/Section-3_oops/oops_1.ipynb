# %%
# hear we are the write code about the opp
def some_function():
    pass

# %%
def log_out():
    pass

# %%
#hear we are the thinking about the object and class 
class login:
    pass #this is the empty class

# %%
# Define the Country class
class Country:
	def __init__(self, name="Unknown"):
		self.name = name

# Create an instance of the Country class
india_co = Country("India")

# %%
class student_form:
    pass
india = student_form()
    
    
india.name = 'india'
india.captol = "delhi"

use = student_form()
use.name = "shivam"
use.gf = 'itisha singh'

print(india.name)
# Out:
# india

# %%
class student_form:
    pass

india = student_form()
india.name = 'india'
india.capitol = "delhi"

use = student_form()
use.name = "shivam"
use.gf = 'itisha singh'

# Printing attributes of each instance
print("Attributes of india:", india.__dict__)
print("Attributes of use:", use.__dict__)
# Out:
# Attributes of india: {'name': 'india', 'capitol': 'delhi'}
# Attributes of use: {'name': 'shivam', 'gf': 'itisha singh'}

# %%
class MTech:
    pass 
pooja = MTech()
pooja.name = 'pooja'
pooja.rool = '242211015'
pooja.relationsip = True

saurabh = MTech()
saurabh.name = "saurabh"
saurabh.rool = '34343454'
saurabh.relationsip = True


if(pooja.relationsip == saurabh.relationsip):
    print('match vibes')
    print("thinking about marriage")
else:
    print("oh no sorry pooja wants to live single")
# Out:
# match vibes
# thinking about marriage

# %%
#write the class of the planet
class planet :
    pass



earth = planet()

earth.name = "earth"
print(earth.name)
# Out:
# earth
